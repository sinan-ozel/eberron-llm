# %%
import os
import re
import json
import pickle

import numpy as np

import torch
from sentence_transformers import SentenceTransformer
# from langchain_mistralai import ChatMistralAI

from tqdm.notebook import tqdm

# %%
DOCUMENT_VERSION = 3
FOLDER = f'/corpus/texts_v{DOCUMENT_VERSION}'

# %%
model = SentenceTransformer('Alibaba-NLP/gte-base-en-v1.5', trust_remote_code=True)
model = model.to("cuda")

# %%
# Are we using cuda? Needs to be True
all([param.is_cuda for param in model.parameters()])
# Out:
# True

# %%
with open('/corpus/metadata.json') as f:
    metadata = json.load(f)
metadata_dict = {}
for data in metadata:
    metadata_dict[data['filename'][:-4]] = data

# %%
include_previous = 1
include_next = 1
drop_if_less_than_n_chars = 100
chunks = []
chunk_metadata = []
chunk_idx = 0
for file_name in os.listdir(FOLDER):
    file_path = os.path.join(FOLDER, file_name)
    with open(file_path) as f:
        document = f.read()
    page_splits = re.split(r'\n## .*\n', document)
    for idx, split in enumerate(page_splits):
        if len(split) < drop_if_less_than_n_chars:
            page_splits[idx] = ''
    page_index = {}
    for idx, split in enumerate(page_splits):

        if idx < include_previous or idx > len(page_splits) - include_next - 1:
            continue
        chunk_metadata.append(metadata_dict.get(file_name[:-3], {'filename': file_name[:-3] + '.pdf'}))
        chunk_metadata[chunk_idx]['pages'] = tuple(range(idx-include_previous, idx+include_next))
        chunks.append('   '.join(page_splits[idx-include_previous:idx+include_next]))
        chunk_idx += 1

# %%
len(chunks), len(chunk_metadata), chunk_metadata[:2]
# Out:
# (7639,
#  7639,
#  [{'filename': '881665-eberron_cannith_cat2.pdf',
#    'edition': '5e',
#    'pdf/title': '',
#    'pdf/author': '',
#    'pages': (2, 3)},
#   {'filename': '881665-eberron_cannith_cat2.pdf',
#    'edition': '5e',
#    'pdf/title': '',
#    'pdf/author': '',
#    'pages': (2, 3)}])

# %%
embeddings = []
for chunk in tqdm(chunks):
    embedding = model.encode(chunk, normalize_embeddings=True)
    embeddings.append(embedding)
# Out:
#   0%|          | 0/7639 [00:00<?, ?it/s]

# %%
with open('embeddings_v01.pkl', 'wb') as f:
    pickle.dump(embeddings, f)

# %% [markdown]
# # Unserialize the Embeddings

# %%
with open('embeddings_v01.pkl', 'rb') as f:
    embeddings = pickle.load(f)

# %%
query = "Who is Dash Donnigan?"
query = "Who is Commander Iyanna?"
query = "Tell me about Menthis Plateau."
query = "Tell me about Eldeen Reaches."
query = "Tell me about the rivers of Khorvaire."
query = "Tell me about Xen'drik."
query = "Tell me about fashion in Khorvaire."
query = "Create a House Cannith item."
query = "Tell me about the lnaguages of Eberron."
query_embed = model.encode(query, normalize_embeddings=True)

# %%
k = 7
similarities = torch.from_numpy(np.dot(embeddings, query_embed.T))
similarities.topk(k).indices.tolist()
# Out:
# [2720, 5585, 2718, 3732, 4294, 4203, 3749]

# %%
for i in similarities.topk(k).indices.tolist():
    print(chunk_metadata[i])
# Out:
# {'filename': 'Eberron_ Rising From the Last War - Jeremy Crawford & James Wyatt & Keith Baker.pdf', 'edition': '5e', 'pdf/title': 'Eberron: Rising From the Last War', 'pdf/author': 'Jeremy Crawford & James Wyatt & Keith Baker', 'pages': (322, 323)}
# {'filename': '1920353-Eberronicon_1.2.pdf', 'edition': '5e', 'pdf/title': 'Eberronicon: A Pocket Guide to the World', 'pdf/author': 'Across Eberron', 'pages': (53, 54)}
# {'filename': 'Eberron_ Rising From the Last War - Jeremy Crawford & James Wyatt & Keith Baker.pdf', 'edition': '5e', 'pdf/title': 'Eberron: Rising From the Last War', 'pdf/author': 'Jeremy Crawford & James Wyatt & Keith Baker', 'pages': (322, 323)}
# {'filename': "Wayfinder's Guide to Eberron - Keith Baker.pdf", 'edition': '5e', 'pdf/title': '', 'pdf/author': '', 'pages': (174, 175)}
# {'filename': '297249-sample.pdf', 'pages': (2, 3)}
# {'filename': '1598836-Languages_of_Eberron_2E.pdf', 'edition': '5e', 'pdf/title': 'Languages of Eberron 2E mk iii', 'pdf/author': '', 'pages': (38, 39)}
# {'filename': "Wayfinder's Guide to Eberron - Keith Baker.pdf", 'edition': '5e', 'pdf/title': '', 'pdf/author': '', 'pages': (174, 175)}

# %%
for i in similarities.topk(k).indices.tolist():
    print(chunks[i])
# Out:
# one-half the total cost af houte expeditions to Xen'drik
# or Cyre, on lung as such expeditions leave from Sharn and
# include #1 least one Cannith South member.
#
# Gear: Members of House Cannith are always well
# cuthtied—anyi hing less would be an affront 10 the house's
# pride. Those on Cannith business are fully outfitted with
# mundane equipment. and those on personal business pay
# only 25% of the mandard con for mundane gear.
#
# Information: Members can have magic items identi-
# fied for 50% of the normal cost and get sccess to maps and
# reports from Cannith explorers in Cyre and Xen'drik,
#
# Access Only members of the house and their assoc i-
# ares have access to the house's forges and workshops.
#
# Favored in House Benefits
#
# Though all members of House Cannith have a level of
# privilege, the split in the house has led to ill will between
# competing factions, Requests from members of Can-
# nith Eas maghi be ignared by Cannith South unless the
# southern faction leely generous or will profit in some
# way. A party fram Cannith West can ask for a warforged
# bodyguard from Cannith South. but have less chance af
# receiving them than a party affiliated with Merrix.
#
# The following table indicates the types of favors a
# Cannith character with the Favored in House fest might
# request, In addinon 10 general favors, rach arm af the
# house can provide special favors. mainly 10 its members.
#
# PLAYING A MEMBER
# OF HOUSE CANNITH
#
# You are 4 proud member of the leader of all dragon-
# marked houses and the creator of the wonders of modern
# Khorvaire. Your social nanding is exceeded only by tha
# of the nobiles of the realm—and not always by them. You
# owe no allegiance to anyone outside the house. and 11 took
# all Five Nations together to pur a leash on the Gorgon,
# the symbol of your Line. Some might call you arrogant,
# bat arrogance and self-assurance are often confused by
# the envious
#
# The wonders of Cannith are known throughous
# the world, snd you feel responsible for continuing tha
# legacy. Whether you have » dragonmark or not, you
# are expected ra contribuie 1a the success of your house
# through invention. scholarship, business, or diplomacy
# Even more iv expected of the dragonmarked heirs of
# Cannith. who serve apprenticeships in the guilds during
# their training. then move up into house business ss their
# (nlente are honed
#
# However, beneath your pride lurks 2 lingering ron:
# cern. No matter where your loyalty lies, you know a house
# divided against sell inevitably falls, and you cannot help
# but feel bitterness toward those who follow these pretend
# ers to the seat af the Gorgon. When your chosen leader
# takes command ol the house, supporters of the would-be
# usurpers will be dealt with Untilihen, Wivup to your side
# to keep Canrith s glory from degenerating further.
#
# Combat
#
# Members af House Cannith never shy away from combat,
# though rhey are seldom found in the thick of it. You use
# every tool al your disposal to ensurs victory, including spells,
# magic Items, and construct mercenaries. As a member
# of the house. you always have the best gear. focusing on
#
# FAVORED IN HOUSE CANNITH
#
# DC' Benefir
#
# 10 One free uae of tha least Mack of Muking; nloan of
# 100 gp wi 10% per month?
#
# 15 One free use of the lesser Mack of Making
#
# 20 Ouse free use of the greater Mark of Making, free
# ume of » Ird-level member of the Fabricators Guild
#
# 25 Free use of a Sth-level member of the Fabricators Guild
# ur Tinkees Guild (lesser dragonmark) for | week
#
# Cannith South Additional Benefits®
#
# DC' Benefit
# 10 Free passage with « house expedition to Xen'drik for
# four characters
#
# 15 Agi of a wand with base value 2,500 gp with 10
# charges left (500 gp value)
#
# 20 Use of n warforged bodyguard (fighter 4) for | week
#
# 25 Free use of a nonexpendable medium wondrous item
# for | week
#
# Cannith West Additional Benefits?
#
# DC" Benefit
#
# 15 Access to the Twelve's magic library for | day
#
# 20 An introduction to a noble from Aundair or Thrane
#
# 25 Use of a sorcerer of the Twelve (sorcerer 5) for | week
#
# Cannith East Additional Bene fis’
#
# DC' Benefit
#
# I5 Training st the Rekkenmark Academy for | week!
#
# 20 Use of 1d4 Rekkenmark cadets (fighter 3) for | week
# 25 Free use of 1d4 Karrnathi zombie soldiers for | week
#
# L Ifo requesied favor involves an illegal or dangerous set,
# Increase the DC hy 5. Favors with DCs of 20 or higher
# always resjurre additional service to the house.
#
# 20 he chpracier requesting a favor 1» from a different
# branch of the house. increase the DC by 5.
#
# TA chacacter can have no more than one loan als lime,
#
# bt Indieidual benefit to be determined by the DM. See Fie
# Notwni for more information on Rekkenmark Academy
#
# pratective or damage -dealing magic items. When Cannith
# goes to battle, there is no such thing as overkill,
#
# Advancement
# In House Cannith, magic is an tntegral par of your
# surroundings. Magical training iy available and steongly
# encouraged, but should you prove incapable af mastering
# the arcane arts, you will be tutored by clan elders an bun
# nes, administration, and dipiomacy. A career in combat
# or divine magic requires a strong will and demonsirable
# aptitude, bur once you gain permission. the house will
# arrange training with the best tutors money can buy. For
# a Cannith, to do anything but excel is unaceeptable
# You know that continued innovation is the fortune
# and lifeblood of your house. Power is the ultimate goal.
# und any steps needed ta attain it are acceptable Thies not
# to say that you personally embrace an ethos of immoral
# ity, hut there can be no doubt that your house does, You
# are wise enough ta pick your battles—whether physical or
# welal—with care. Once committed, you accept nothing
# less than complete victory, no matter what it takes,
#
# -
# =
# m
# =
# jo}
# c
# wh
# m
# wi
#
#
#
# Missions
# The missions House Canoith assigns depend on your fac-
# tion. In Cannith South, you might explore the Mournland
# or Xen'drik. Alternatively. you might travel on diplomatic
# missions to Cannith East or West, playing one agains the
# other. You could be appointed an emissary to Morgrave
# University, examining new finds. You might even repart
# to Merria with sny information you gain—or the liems
# themselves, if possible
#
# Asamember of Cannith West. you might accompany
# agents of the Twelve on expeditions as far away as Argon-
# nessen or Sarlons, representing your house. You might
# research ancient drurd ruins in the Eldeen Reaches You
# could be sent to a gals to enlighten an important noble on
# a matter that concerns your house. You might even hud
# yourself engaged |n espionage under cover of guild men -
# bership, traveling ne rass Khorvaiee in support of Jorlunna
# d'Cannith’s ambition te rule—or inadvertently swrving
# the Lords of Dust ay they manipulate that ambition
#
# For Canniuth East. you might find yourself loaned 10
# Karrnath in pursuit of Emerald Claw agents, meetingwirh
# Lhazaarite princes to discuss business endeavors, [aining
# the dwarf lards af the Mror Holds jo stave off an incursion
# from Khyber. or leading a unit of undead and constructs
# on u clandestine mission for the Karrnathi crown
#
# HOUSE CANNITH IN THE WORLD
#
# Jaron d'Conmith I remember him well. We were overrun by ghouls.
# and without « blink; he vant spells and left tur gurds wandin' like stiles
# eught vo the path. Gave us time to run, but ean stil) hear the screams ”
#
# —Ciunrd Brennan Enshield. Sharn Watch
#
# Wherever magreal power can be gained, House Cannith
# Is nearby. Not content 1o let the Twelve do their work for
#
# them, the scions of the house claim any resource that
# might help them regain thelr farmer glory or exceed their
# previous schievemente—ay quietly as possible. of course
# Though the house is not wholly evil, many within Cannuh
# can hardly be called souls of truth and righteousness. Asa
# base of operations for the PCs, a bastion against ruly dark
# forces in the world. or un evil empire, House Cannith can
# be a powerful force in any campaign
#
# I'he lust patriarch, Starrin d’Cannith left a lasting
# imprint on his house Though Merrixand Aarren created
# the warforged, Starrin engaged the warring stbling kings
# of the Five Nations, persyading them both of Cannuth«
# neutrality and of the warforged's usefulonwss in battle. Fis
# death wan a blow from which the house hus yet to recover
#
# Instead of a single patriarch, Cannith currently has
# three descendants claiming the title af baron, cach man
# aging a portion of the house's concerns, Though s council
# of lords seneschal would typically reign over the viceroys,
# Merris, Jordanns and Zorlan's nominal status as the hears
# to the sent of the Gorgon effectively makes them a trium-
# virme. over which the lords seneschal have Little comrol.
#
# Promation within the house is judged by one’s con-
# tributions lo Cannith's continued growth and well-being.
# Members must strive if they wish to become more powerful
# within the hierarchy Those who succeed are either brii-
# faant «ft invention, uncannily aware of others motives, or
# both House members with ne taste for politics succesd
# by lending their support to those so inclined
#
# NPC Reactions
#
# House Cannith’s posirion as the nominal lesder of the
# dragonmarked houses goes largely unchallenged. Cannith
# and Deneith work well together, and individuals from
# House Deneith and the Twelve have an initial reaction of
#
# EE —————————————————
#
# Guns iv House CANNITH
#
# The roots of House Cannith ure in its guilds, the his.
# torical face of the house and the most ummon Can-
# nith presence outside lv enclaves, The hulk of house
# business actually goes on outside the guilds, which are
# seen by house members as only training grounds or
# career looinoles.
#
# Fasricatrors GuiLn
#
# The Fabiricatars Guild is 0 mercantile branch of House
# Cannith, well knows as a training ground lor arcane
# spelleastors and dragon marked heirs. Outside the house,
# the Fabricators Guild has a reputation for fine. reliable
# goods. Guild shops offer 4 complete range of mundane
# equipment, and some sccepl commissions for unusual
# nonmagical tems, Though mos guild members keep to
#
# FABRICATORS GUILD
#
# Associated Classes: Artificer, rxpert, magewright,
# witard,
# Associated Skills: Appraise, Craft, Diplomacy.
# Cather Information, Knowledge (local)
#
# cities. some heirs are commissioned to travel with cara-
# Yana and ships, lO create Or repair fquipment
#
# Tinkers Guito
#
# The Tinkers Guild (» 4 mercantile branch of House Can-
# nith, and hearkens back 1o the origins of the house. Cannith
# was born from groups of human tinkers that moved from
# town ta town, repairing broken items or making new ones
# to sell. The guild has a virtual monopely on the repair of
# mundane objects, primarily by members with the least ar
# lesser Marks of Making. Most Dragonmarked heirs of Can-
# mith serve at least two years in the guild. acting as the public
# face of the house in Khorvaire. Those dragonmarked wha
# decide that rank snd power are not for them sometimes
# remain in the guild. balancing a lack of respect from others
# in the house with a lite of relative freedom.
#
# TINKERS GUILD
# Associated Classes: Expert, fighter, rogue, warrior.
#
# Associated Skills, Appraise. Diplomacy, Crafr,
# Knowledge (local), Profession (tinker).
#
# Barer ——————————————————
#
#
#
# Missions
# The missions House Canoith assigns depend on your fac-
# tion. In Cannith South, you might explore the Mournland
# or Xen'drik. Alternatively. you might travel on diplomatic
# missions to Cannith East or West, playing one agains the
# other. You could be appointed an emissary to Morgrave
# University, examining new finds. You might even repart
# to Merria with sny information you gain—or the liems
# themselves, if possible
#
# Asamember of Cannith West. you might accompany
# agents of the Twelve on expeditions as far away as Argon-
# nessen or Sarlons, representing your house. You might
# research ancient drurd ruins in the Eldeen Reaches You
# could be sent to a gals to enlighten an important noble on
# a matter that concerns your house. You might even hud
# yourself engaged |n espionage under cover of guild men -
# bership, traveling ne rass Khorvaiee in support of Jorlunna
# d'Cannith’s ambition te rule—or inadvertently swrving
# the Lords of Dust ay they manipulate that ambition
#
# For Canniuth East. you might find yourself loaned 10
# Karrnath in pursuit of Emerald Claw agents, meetingwirh
# Lhazaarite princes to discuss business endeavors, [aining
# the dwarf lards af the Mror Holds jo stave off an incursion
# from Khyber. or leading a unit of undead and constructs
# on u clandestine mission for the Karrnathi crown
#
# HOUSE CANNITH IN THE WORLD
#
# Jaron d'Conmith I remember him well. We were overrun by ghouls.
# and without « blink; he vant spells and left tur gurds wandin' like stiles
# eught vo the path. Gave us time to run, but ean stil) hear the screams ”
#
# —Ciunrd Brennan Enshield. Sharn Watch
#
# Wherever magreal power can be gained, House Cannith
# Is nearby. Not content 1o let the Twelve do their work for
#
# them, the scions of the house claim any resource that
# might help them regain thelr farmer glory or exceed their
# previous schievemente—ay quietly as possible. of course
# Though the house is not wholly evil, many within Cannuh
# can hardly be called souls of truth and righteousness. Asa
# base of operations for the PCs, a bastion against ruly dark
# forces in the world. or un evil empire, House Cannith can
# be a powerful force in any campaign
#
# I'he lust patriarch, Starrin d’Cannith left a lasting
# imprint on his house Though Merrixand Aarren created
# the warforged, Starrin engaged the warring stbling kings
# of the Five Nations, persyading them both of Cannuth«
# neutrality and of the warforged's usefulonwss in battle. Fis
# death wan a blow from which the house hus yet to recover
#
# Instead of a single patriarch, Cannith currently has
# three descendants claiming the title af baron, cach man
# aging a portion of the house's concerns, Though s council
# of lords seneschal would typically reign over the viceroys,
# Merris, Jordanns and Zorlan's nominal status as the hears
# to the sent of the Gorgon effectively makes them a trium-
# virme. over which the lords seneschal have Little comrol.
#
# Promation within the house is judged by one’s con-
# tributions lo Cannith's continued growth and well-being.
# Members must strive if they wish to become more powerful
# within the hierarchy Those who succeed are either brii-
# faant «ft invention, uncannily aware of others motives, or
# both House members with ne taste for politics succesd
# by lending their support to those so inclined
#
# NPC Reactions
#
# House Cannith’s posirion as the nominal lesder of the
# dragonmarked houses goes largely unchallenged. Cannith
# and Deneith work well together, and individuals from
# House Deneith and the Twelve have an initial reaction of
#
# EE —————————————————
#
# Guns iv House CANNITH
#
# The roots of House Cannith ure in its guilds, the his.
# torical face of the house and the most ummon Can-
# nith presence outside lv enclaves, The hulk of house
# business actually goes on outside the guilds, which are
# seen by house members as only training grounds or
# career looinoles.
#
# Fasricatrors GuiLn
#
# The Fabiricatars Guild is 0 mercantile branch of House
# Cannith, well knows as a training ground lor arcane
# spelleastors and dragon marked heirs. Outside the house,
# the Fabricators Guild has a reputation for fine. reliable
# goods. Guild shops offer 4 complete range of mundane
# equipment, and some sccepl commissions for unusual
# nonmagical tems, Though mos guild members keep to
#
# FABRICATORS GUILD
#
# Associated Classes: Artificer, rxpert, magewright,
# witard,
# Associated Skills: Appraise, Craft, Diplomacy.
# Cather Information, Knowledge (local)
#
# cities. some heirs are commissioned to travel with cara-
# Yana and ships, lO create Or repair fquipment
#
# Tinkers Guito
#
# The Tinkers Guild (» 4 mercantile branch of House Can-
# nith, and hearkens back 1o the origins of the house. Cannith
# was born from groups of human tinkers that moved from
# town ta town, repairing broken items or making new ones
# to sell. The guild has a virtual monopely on the repair of
# mundane objects, primarily by members with the least ar
# lesser Marks of Making. Most Dragonmarked heirs of Can-
# mith serve at least two years in the guild. acting as the public
# face of the house in Khorvaire. Those dragonmarked wha
# decide that rank snd power are not for them sometimes
# remain in the guild. balancing a lack of respect from others
# in the house with a lite of relative freedom.
#
# TINKERS GUILD
# Associated Classes: Expert, fighter, rogue, warrior.
#
# Associated Skills, Appraise. Diplomacy, Crafr,
# Knowledge (local), Profession (tinker).
#
# Barer ——————————————————
#
#
# friendly to Cannith members. Members
# of the other dragonmarked houses
# have an initial reaction of indifferent
# Notable exceptions include members
#
# of Tharashk and Vadalis, both of
# whom dislike Cannith's questionable
# morals and power-hungry ways. Mem-
# bern of those two houses often have an
# imitial attitude of unfriendly
#
# HOUSE CANNITH LORE
#
# Characters with ranks in Knowledge
# (arcana) or Knowledge (nohility and
# royalty) can research House Cannich
# ta learn more about 1. When a char
# peter succeeds on a skill check, the
# fullowing lore is revealed, including
# the information from lower DCs,
#
# DC 10: House Cannith isthe power
# behind the Tinkers Guild and Fabricators
# Guild. lt can be found across the land, and
# dominate the craft industry
#
# DC 15: Same members of House Cannith have the
# Mark of Making. and can create or repair using magic.
#
# DC 20: House Cannith created the warforged and
# wld them 10 many nations. The Treaty of Thronehold
# gove the warforged the same rights as other individuals
# and forbade Cannnh from ¢rearing more,
#
# DC 30. Characters who achieve this level ol success
# can lesen important details about House Cannith in your
# campaign. including history. notshle members. the areas
# where il operates, and the kinds of activities ot undertakes
#
# »
#
# HOUSE CANNITH'S HOLDINGS
# hough Cannith loss Whitehearith, Merrix d Cannith's
# enclave in Sharn has taken over the house's creative work.
# The Sharn enclave is the practical headquarters for the
# business of the house, bur those with political or invest-
# meni interests more often approach Jorlanna or Zoran.
#
# Many look ta Sharn for new wonders, but Cannith i»
# not limited 10 one facility. The house has holdings scross
# the continent. und beyond. Though Sharn has the only
# curren| fargehoid, Cannuh estates are lound in Fairhaven,
# Flamekeep, Korth, Throneport, and Trolanport. with
# wmall outposts at Regalport and Varna. Abroad, the house
# has holdings in Pylas Talaear on Aerenal and in Storm-
# reach on Xen'drik, The Tinkers Guild and Fabricators
# Guild are found in every major city in the Five Nations.
# and in larger centers in the lands beyond
#
# MEMBERS OF HOUSE CANNITH
# IN THE GAME
#
# Any campaign involving the Mournland, Sharn, Xen'drik.
# Aundair, or Karenath can naturally include Cannuhasan
# ally or enemy. Cannith NPCsare proud, often bordering
# onarrogant, They are also practical, looking at situations —
# ind people —fram a standpoint of profit and loss.
#
# Adaptation
#
# House Cannith can remain central to almost any cam-
# patgn. Without the warfarged, Cannith could still be a
# lormer weapons supplier, now hand capped by the Treaty
# of Thronchold. The Day of Mourning and the devastation
#
# Jaxon d'Cannidh,
# sorcerer extraordinaire
#
# the house suffered could be replaced by u natu-
# ral disaster. ADM can even take dragonmarks
# out of the picture, leaving an organization of
# arcanists and artificers converting magical
# innovasion into wealth and power.
#
# Sample Encounter
# An casy way for characters 10 compete
# with House Cannlth Is over relics
# ~ from Cyre or Xen'drik. Any new
# acquisition from Xen'drik Inter:
# RD ests Merrix, especially warforged
# schemas. House Cannith has a cadre
# of agents patrolling not just the university but
# all the levels of Sharn. looking for information,
# Hems, or threats to Cannith security
# EL 8; Jaxon d"Cunnith ix charged with protecting
# Cannith interests, He often serves ar an escort inte
# the lowes levels of Sharon, using hisspellsro
# ensure the safety of house members He in
# escorting a pair of house dignitaries when
# they are ambushed by three members ol a
# local gang (Hth-level changeling rogues). The conflict draws
# the attention of those passing by, including the PCy
#
# CR 6
#
# SASNOH 4H)
#
# JAXON D'CANNITH
#
# Male human sorcerer b
#
# LN Medium humanoid
#
# Init +f; Senses Listen «0, Spor «0
# Languages Common, Gnome
#
# AC 17 rouch |Z. Hat-footed 15
# («2 Des, +4 armor «| nwursll
# hp 25 (6 HIN
# Resixt ring of counterspells (hold person}
# Fort +3, Ref «+4, Will +5
# Speed 30 1 (6 squares)
# Melee «1 dagger +3 (1da/ 19-20)
# Ranged mwk dagger +6 (1d4- 1719-20)
# Base Atk +3 Grp <7
# Combat Gear 2 potion uf cure light woimil
# Sorcerer Spells Known (CL Bil)
# Ted (4/dnyd—hold pereon (DC 1k)
# 2nd (6/day)— vummon monster [T, web (DIC 15)
# Lar (7/day)—bermng hand (DC 14], harm person LOE 14), mage
# armor? mien mule
# 0 (6/dwy) — detect mags, detect parson, dhsrupl undead, flare {DC 1),
# light. mewge, read magi
# I Already can
# Spell- Like Abilities (CL 1h)
# Liday~moly whol
# | /day—minoe creation
# Abilities Sir 8, Des 14 Con 15, Int 12 Wis [0 Cha 16
# SQ familiar (none)
# Feats Improved Insiative Least Drsgonmark (Mark of Making),
# Lesser Dragonmark (Mack of Making), Toughness
# Skills Bluff «8, Craft (alchemy) «7, Concentration +8, Die
# guise +3 (45 to ct in character), lntimidate «5. Knowledgs
# arcana) <1], Listen <b. Spellcraft «13. Spor +0
# Possessions combat gear plus emulel of soto) arma #1, +! dagger,
# 2 mavierwork daggers. rimg of counterpells
#
# Hook “Most people think iwice about threatening « Cannuh,
# Too bad you won'l get that chance ” —
#
#
#
# S
#
# THE HOLISE
#
# 270
#
# Both Zorlan and Merrix remain unaware
# thar Jorlanna’s romantic indiscretions are
# not entirely behind her. For a year now,
# Jorlanna has been clandestinely involved
# with a young seion of House Orien—never
# realizing that her lover is actually a vakshasa
# agent of the Lords of Dust, The fiends
# immediate gaul ure fracture House Can
# sith permanently, and he manipulates
#
# Jorlanna ta that end
#
# CANNITH EAST
#
# 1 hough Zorlan gfrw ap in Cyre
# he Haveled to Karrmath as & house
# emissary along with the first wae
#
# forged ordered by that nation. He
#
# took up residence here, advising
# Knias 1 and strengthening hi
# house's influence. He used profu
#
# House Cannurh is a dragonmarked house of
# humans who carry the Mark of Making in
# their bloodlines. [Ls among the leaders of
# the drugonmarked houses, and the greacest
# artifice of modern Kharvalee is of Can
# mith design
#
# JOINING HOUSE
# CANNITH
#
# Membervhip in House Can
# nih as primarily by blood
# thaugh more than a few mem-
# bers have entered through
# marrage. Hirelings receive ben
# efits. such us equipment. and recognition,
#
# but are Little more than servants as far as
# mm Cann wroncerned, A rare lew associates
#
# might be recognized ax hanaratry members
# : 8
#
# able wrrangemenis with the Mror Haldiand Baron Jorlanna d'Cannith afer long wivice, oreven given the opportu
#
# the | hazasr Principalities 1o fill hay coffers
# wind make himelf an advisor wo the Gorgon.
#
# Where Cannith once had only an ouwrpon in Karr
# nath. Zorlan's lsadecship has seen the house's wealth and
# prestige there grow, Before the Day of Mourning, many
# Coannith heirs were sent 1o Karrnoth to study adminis
# tralian and diplomac v. and 10 receive man ial tRstructon
# Irom Rekkenmark Academy This teaining ended with
# the Iracture of the Canntth leadership. but many heirs
# sill proudly recall their Karrnath yenrs ©
#
# Though the steady stream of warforged into Kars
# with has ceased, Cannith East still hag prpertise in siege
# warfpre, and house members serve as advisors to
# Karrn generals
#
# The Karroachi culture has left 114 mark an
# Cannith East. Members lake a callous view of mor-
# tality, viewing the undead as lictle more than the
# necromantic equivalent of warforged. Though
# iwention is Cannith East's strength, andes
# ine researg Ih al Lis orig lave see ky Lod reale p nrw
# form of construct undesd. ammated
# with eldriteh power and a bound
# ghostly intelligence
#
# Living amang the Karrns
# has led many of Cannnh wo
# worship the Blood of Val
# | hough Cannith would ever
# openly declare allegiance w
# any other power group, nearly
# half ihe members ol the Karrn
# ath enclave are said to lollow that
# fwith. Zoran is u devon member
# evils apiring 10 4 pasion in Lhe
# cules Tay lergy and peronally con
# ducting services for hause members on
#
# ipecial occasions
#
# House CANNITH
# AS AN ORGANIZATION
#
# “Wr alone har created 0 new form of fife—ond that ll be the least of
# our achivoements.”
# —Aarren d'Cannith
#
# of Fairhaven
#
# tty to marry indo the family. Warforged are
#
# never recognized as members of the house
# In House Cannuth, urtibicers, sorcerers and wizards
# are common, gen the house s focus on magical creanon,
# Members unskilled in arcane magic find i dalfiealt lo rise
# within the ranks. Charseters who are members of House
# Cannith must choose Cannith South, Weal. or East
#
# TRY REQUIREMENTS
#
# Race: Human,
# Special Must be relaed 10 0 member of House Cannith
#
# by bined or marriage
#
# House Cannuh relies on magical research and iavennion
# tremam prosperous and Arvanivsare the house t
# lifeblood. Wizards resenrch new ideas and evaluate
# magic from ouside the house. fram uncient relics
# to the latest spells Artificers transform that
# wudy mio Phy wean! reality and they cont rol
# the use of the Cannuh-creared nema
# Soteerers represent the house
# inthe weder world underzak
# ing expeditions guarding
# inventions, and retrieving
# lar eliminating) relics and
#
# people AL TEL ENAGTY
#
# HOUSE CANNITH
# BENEFITS
#
# Given Lannith's position as an
# mm affluent and inlluential house, Ls mem
#
# bere have access to a wide range al hen
#
# Baron Zorlan d'Cannith efits. However. the aftermath of the Day
#
# of Korth
#
# of Mourning has left 1he house divided in
#
# resources as well as loyalties
# Economies: House Cannith covers mugly items,
# especially those of Cyre und Xen'drik, Members who
# find such tems are strongly encouraged 10 bring them
# vo the house which then reveard hes them or loans them
# ro those noo house assignment) Items are evalunted, and
# the member wha found them (+ paid 63% of the estimated
# worth, In addition, Cannith South will subsidize up 10
#
#
# one-half the total cost af houte expeditions to Xen'drik
# or Cyre, on lung as such expeditions leave from Sharn and
# include #1 least one Cannith South member.
#
# Gear: Members of House Cannith are always well
# cuthtied—anyi hing less would be an affront 10 the house's
# pride. Those on Cannith business are fully outfitted with
# mundane equipment. and those on personal business pay
# only 25% of the mandard con for mundane gear.
#
# Information: Members can have magic items identi-
# fied for 50% of the normal cost and get sccess to maps and
# reports from Cannith explorers in Cyre and Xen'drik,
#
# Access Only members of the house and their assoc i-
# ares have access to the house's forges and workshops.
#
# Favored in House Benefits
#
# Though all members of House Cannith have a level of
# privilege, the split in the house has led to ill will between
# competing factions, Requests from members of Can-
# nith Eas maghi be ignared by Cannith South unless the
# southern faction leely generous or will profit in some
# way. A party fram Cannith West can ask for a warforged
# bodyguard from Cannith South. but have less chance af
# receiving them than a party affiliated with Merrix.
#
# The following table indicates the types of favors a
# Cannith character with the Favored in House fest might
# request, In addinon 10 general favors, rach arm af the
# house can provide special favors. mainly 10 its members.
#
# PLAYING A MEMBER
# OF HOUSE CANNITH
#
# You are 4 proud member of the leader of all dragon-
# marked houses and the creator of the wonders of modern
# Khorvaire. Your social nanding is exceeded only by tha
# of the nobiles of the realm—and not always by them. You
# owe no allegiance to anyone outside the house. and 11 took
# all Five Nations together to pur a leash on the Gorgon,
# the symbol of your Line. Some might call you arrogant,
# bat arrogance and self-assurance are often confused by
# the envious
#
# The wonders of Cannith are known throughous
# the world, snd you feel responsible for continuing tha
# legacy. Whether you have » dragonmark or not, you
# are expected ra contribuie 1a the success of your house
# through invention. scholarship, business, or diplomacy
# Even more iv expected of the dragonmarked heirs of
# Cannith. who serve apprenticeships in the guilds during
# their training. then move up into house business ss their
# (nlente are honed
#
# However, beneath your pride lurks 2 lingering ron:
# cern. No matter where your loyalty lies, you know a house
# divided against sell inevitably falls, and you cannot help
# but feel bitterness toward those who follow these pretend
# ers to the seat af the Gorgon. When your chosen leader
# takes command ol the house, supporters of the would-be
# usurpers will be dealt with Untilihen, Wivup to your side
# to keep Canrith s glory from degenerating further.
#
# Combat
#
# Members af House Cannith never shy away from combat,
# though rhey are seldom found in the thick of it. You use
# every tool al your disposal to ensurs victory, including spells,
# magic Items, and construct mercenaries. As a member
# of the house. you always have the best gear. focusing on
#
# FAVORED IN HOUSE CANNITH
#
# DC' Benefir
#
# 10 One free uae of tha least Mack of Muking; nloan of
# 100 gp wi 10% per month?
#
# 15 One free use of the lesser Mack of Making
#
# 20 Ouse free use of the greater Mark of Making, free
# ume of » Ird-level member of the Fabricators Guild
#
# 25 Free use of a Sth-level member of the Fabricators Guild
# ur Tinkees Guild (lesser dragonmark) for | week
#
# Cannith South Additional Benefits®
#
# DC' Benefit
# 10 Free passage with « house expedition to Xen'drik for
# four characters
#
# 15 Agi of a wand with base value 2,500 gp with 10
# charges left (500 gp value)
#
# 20 Use of n warforged bodyguard (fighter 4) for | week
#
# 25 Free use of a nonexpendable medium wondrous item
# for | week
#
# Cannith West Additional Benefits?
#
# DC" Benefit
#
# 15 Access to the Twelve's magic library for | day
#
# 20 An introduction to a noble from Aundair or Thrane
#
# 25 Use of a sorcerer of the Twelve (sorcerer 5) for | week
#
# Cannith East Additional Bene fis’
#
# DC' Benefit
#
# I5 Training st the Rekkenmark Academy for | week!
#
# 20 Use of 1d4 Rekkenmark cadets (fighter 3) for | week
# 25 Free use of 1d4 Karrnathi zombie soldiers for | week
#
# L Ifo requesied favor involves an illegal or dangerous set,
# Increase the DC hy 5. Favors with DCs of 20 or higher
# always resjurre additional service to the house.
#
# 20 he chpracier requesting a favor 1» from a different
# branch of the house. increase the DC by 5.
#
# TA chacacter can have no more than one loan als lime,
#
# bt Indieidual benefit to be determined by the DM. See Fie
# Notwni for more information on Rekkenmark Academy
#
# pratective or damage -dealing magic items. When Cannith
# goes to battle, there is no such thing as overkill,
#
# Advancement
# In House Cannith, magic is an tntegral par of your
# surroundings. Magical training iy available and steongly
# encouraged, but should you prove incapable af mastering
# the arcane arts, you will be tutored by clan elders an bun
# nes, administration, and dipiomacy. A career in combat
# or divine magic requires a strong will and demonsirable
# aptitude, bur once you gain permission. the house will
# arrange training with the best tutors money can buy. For
# a Cannith, to do anything but excel is unaceeptable
# You know that continued innovation is the fortune
# and lifeblood of your house. Power is the ultimate goal.
# und any steps needed ta attain it are acceptable Thies not
# to say that you personally embrace an ethos of immoral
# ity, hut there can be no doubt that your house does, You
# are wise enough ta pick your battles—whether physical or
# welal—with care. Once committed, you accept nothing
# less than complete victory, no matter what it takes,
#
# -
# =
# m
# =
# jo}
# c
# wh
# m
# wi
#
#
#
#
# shapers; these living weapons become treasured heirlooms
# of the cult, and are passed down from priest to priest.
# Some Khyber cults seek power and may even have a
# vaguely rational plan for acquiring it, but most are driven
# by madness. Regardless of how sane or structured they may
# seem on the surface, the vast majority of cultists are funda-
# mentally unstable. Virtually all cultists have no regard for
# life. Most consider themselves to be the chosen children
# of the Dragon Below, and the lives of the creatures around
# them are no more meaningful than those of insects.
#
# Typical Dragon Below Cultist: Human rogue 2/cleric 2
# (the Dragon Below): CR 4; Medium humanoid; HD 2d6
# plus 2d8; hp 18; Init +6; Spd 30 ft.; AC 16, touch 12, flat-
# footed 14; Base Atk +2; Grp +4; Atk +6 melee (1d6+2/x4,
# masterwork heavy pick) or +4 melee (1d6+2/19—20, short
# sword) or +5 ranged (1d6+2/X3, composite shortbow
# with masterwork arrow); Full Atk +6 melee (1d6+2/X4,
# masterwork heavy pick) or +4 melee (1d6+2/19—20, short
# sword) or +5 ranged (1d6+2/%3, composite shortbow with
# masterwork arrow); SA rebuke undead 2/day (—1, 2d6+1,
# 2nd), sneak attack +1d6; SQ evasion, trapfinding; AL NE;
# SV Fort +3, Ref +5, Will +4%; Str 14, Dex 15, Con 10, Int
# 12, Wis 14, Cha 8.
#
# Skills and Feats: Balance +4, Bluff +4, Concentration +2,
# Diplomacy +1, Disable Device +6, Escape Artist +7, Gather
# Information +4, Heal +3*, Hide +6, Intimidate +1, Jump
# +4, Knowledge (religion) +3, Listen +2%, Move Silently
# +7, Search +6, Spellcraft +3, Spot +6%, Survival +3* (when
# following tracks), Tumble +7, Use Rope +4 (involving
# bindings); Augment Summoning®, Improved Initiative,
# Weapon Focus (heavy pick).
#
# *Includes —1 penalty for having the Madness domain.
#
# Languages: Common, Undercommon.
#
# Possessions: Masterwork studded leather, masterwork
# light wooden shield, masterwork heavy pick, short sword,
# composite shortbow (+2 Str bonus) with 15 masterwork
# arrows, holy symbol (the Dragon Below), scroll of doom,
# scroll of magic weapon.
#
# Cleric Spells Prepared (4/4; save DC 12 + spell level):
# 0—detect magic, light, mending, read magic; 1st—cause fear, lesser
# confusion”, obscuring mist, summon monster I.
#
# D Domain spell. Domains: Dragon Below (Augment
# Summoning as a bonus feat), Madness (once per day, add
# +2 to a single Wisdom-based skill check or Will save before
# the roll is made).
#
# DRAGONMARKED HOUSES
#
# The dragonmarked houses have existed for thousands
# of years. For some reason not completely understood,
# the common races living on the continents of Khorvaire
# and Aerenal developed dragonmarks and the spell-like
# abilities associated with them. Some sages believe that the
# abundance of Eberron dragonshards on these continents
# has something to do with the development of dragonmarks,
# but no one can prove this theory. What is known is that
# humans and elves never manifested dragonmarks while
# living in the Eberron-dragonshard-deficient regions of
# Sarlona and Xen’drik.
#
# Individual dragonmarks appeared within bloodlines,
# and soon family dynasties sprang up to take advantage
# of the dragonmark powers. Each family created an eco-
# nomic empire using the dragonmarks, and the dragon-
# marked houses developed into independent commerce
# states operating across multiple nations. The War of the
# Mark, which ended about fifteen hundred years ago,
# stabilized the houses and ended the threat of aberrant
# and mixed marks that might have destroyed the economy
# of Khorvaire. Today, twelve dragonmarks shared among
# thirteen houses form the basis for economic power across
# the continent.
#
# Agreements reached at the end of the War of the
# Mark formalized tenets and traditions that all the houses
# adhere to. These include rules concerning neutrality (all
# houses make a show of remaining neutral so that they can
# operate in all nations), fair trade and practices, family
# naming conventions, and a ban on marriages between
# houses so that the dragonmarks remain pure.
#
# Family members run each house, with either a matri-
# arch or patriarch serving as the chief executive of both
# family and economic business. House family members
# form an economic aristocracy on par with the royal and
# noble families of the various nations, and family lead-
# ers are literally barons of industry and commerce. Each
# house also employs retainers and hirelings to aid in the
# family business. Those retainers and hirelings who show
# initiative and promise can rise through the ranks to hold
# important positions within the house. The most effective
# and promising of these might be invited into the family
# through marriage to the young scions of the blood, thus
# making sure the bloodline continues.
#
# Even though the house blood flows through the
# veins of every family member, not every one of them has
# a dragonmark; only a small percentage of every genera-
# tion manifests a mark. Among those who do, the least
# mark is the most common to appear, with fewer lesser
# marks, and fewer still greater marks appearing in each
# generation. Those who do develop a dragonmark are
# singled out for great things and have responsibilities
# to the family that scions without marks never have to
# worry about.
#
# HOUSE CANNITH
#
# House Cannith, consisting of humans with the Mark of
# Making, includes alchemists, artificers, and magewrights
# of great skill, as well as the best mundane crafters on the
# continent. House Cannith arose in pre-Galifar Cyre
# almost twenty-five hundred years ago. Originally, the
# Cannith clan consisted of traveling tinkers, repairers,
# and crafters whose burgeoning dragonmarks gave them
# an edge over the competition. As the house developed, it
# turned its attention to supernatural disciplines, study-
# ing alchemy and pioneering the techniques of artificers
# and magewrights. As builders, fixers, and creators, the
# house maintains a lawful outlook. Some of its greatest
# accomplishments include the lightning rail, the war-
# forged, and the high-rising towers of Sharn.
#
# The destruction of Cannith’s ancestral estates in Cyre
# and the death of the patriarch have thrown the house into
#
# 0
# =
# 0
# >
# =
# >
# =
# S
# =
# wn
#
# 231
#
#
# nN
# =
# 2
# =
# <
# >
# =
# <
# Oo
# 4
# oO
#
# 232
#
# chaos. Three leaders have emerged, each intending to
# lead the house into the future. While the situation
# hasn't yet grown as bad as the split in the Mark
# of Shadow family that resulted in the cre-
# ation of a new house, none of the emerging
# Cannith leaders is willing to accept the
# others as the new house patriarch. So far,
# they have reluctantly shared influence
# in the family by concentrating on their
# own regions and not attempting to pull
# the entire family together.
#
# Baron Jorlanna d'Cannith (LN female
# human, wizard 8) operates out of Fairhaven
# and oversees the house's efforts in Aundair,
# Thrane, and the Eldeen Reaches. Baron
# Merrix d’Cannith (LE male human, arti-
# ficer 9/dragonmark heir 3) leads the house’s
# activities in Breland, Zilargo, and Darguun from hold-
# ings in Sharn. Baron Zorlan d’Cannith (NE male human,
# artificer 3/sorcerer 4/dragonmark heir 1) controls house
# operations in Karrnath, the Mror Holds, and the Lhazaar
# Principalities from an enclave in Korth.
#
# House Cannith maintains two guilds. The Tinkers
# Guild serves to maintain society by repairing damaged
# structures and vehicles, maintaining infrastructures in
# the major cities, and performing similar crafts. Cannith
# tinkers often travel on circuits between smaller villages,
# using magical and mundane skills to assist communities
# that they pass through. The Fabricators Guild performs
# the greatest works of craft, artifice, and magic. The guild
# is divided into dozens of specialties, including architects,
# elemental binders, alchemists, and armorers. The Fabri-
# cators Guild closely guards the secrets of its creation pat-
# terns. With one of these patterns (each made up of three or
# more sections called schemas), a member of the guild can
# replicate an item faster and with less effort than someone
# working without a pattern.
#
# The services provided by House Cannith are invalu-
# able, and all the nations and dragonmarked houses have
# an interest in maintaining friendly relations with the
# House of Making. House Cannith’s greatest enemy is
# itself. Both Jorlanna and Zorlan seek to gain
# control of the entire house, while Merrix is
# content to rule over the southern interests
# and continue his secret experiments deep
#
# beneath Sharn.
#
# Typical House Cannith Magewright:
# Human magewright 3; CR 2; Medium
# humanoid; HD 3d4+3; hp 10; Init +0;
# Spd 30 ft.; AC 10, touch 10, flat-footed
# 10; Base Atk +1; Grp +0; Atk +0 melee
# (1d3-1, unarmed attack) or +1 ranged
# (1d6 fire, flask of alchemist’s fire); Full
# Atk +0 melee (1d3—1, unarmed attack) or
# +1 ranged (1d6 fire, flask of alchemist’s fire);
# SA spells; AL NG; SV Fort +2, Ref +1, Will +5;
# Str 8, Dex 11, Con 12, Int 13, Wis 10, Cha 9.
# Skills and Feats: Concentration +8, Craft (alchemy)
# +5, Craft (blacksmithing) +5, Knowledge (arcana)
#
# +5, Knowledge (architecture and engineering) +5,
#
# Spellcraft +8; Iron Will, Skill Focus (Concen-
# tration), Skill Focus (Spellcraft).
# Languages: Common, Gnome.
#
# Magewright Spells Prepared (3/3; save DC
#
# 11 + spell level): 0—mage hand 3); Ist—mage-
#
# craft (3).
#
# : Possessions: Artisan’s outfit, artisan’s
#
# “tools, flask of alchemist’s fire, 6 tinder-
# twigs, identification papers.
#
# HOUSE DENEITH
#
# The proud humans of House Deneith carry
# the Mark of Sentinel. Born in pre-Galifar
# Karrnath about twenty-six hundred years
# ago, today the house offers the services of
#
# the Defenders Guild and Blademarks Guild,
# one devoted to protection and the other to supply mer-
# cenaries to the highest bidders. From his base of opera-
# tions in Karrlakton, Baron Breven d’Deneith (LN male
# human, aristocrat 3/fighter 3/dragonmark heir 4) con-
# trols the guilds and oversees the activities of the Sentinel
# Marshals who, by ancient decree, provide law and order
# across national boundaries.
#
# Since the rise of Galifar, House Deneith has held to a
# military structure. Heirs of the house are expected to serve
# in the Defenders Guild, the Blademarks, or the Sentinel
# Marshals, and leaders of the house are usually chosen from
# the generals of the Blademarks.
#
# Because of its mercenary forces, Deneith holds the
# most significant military power among the dragonmarked
# houses. In the past, it has strictly abided by its vow of
# neutrality, selling its services to those on both sides of any
# conflict. With the Five Nations weakened by the Last War,
# some within the house feel that it is time for Deneith to
# exercise its power to forge a new kingdom. Chief among
# these activists is Shirin d’Deneith (LE male human,
# rogue 3/fighter 4/dragonmark heir 2), Lord Commander
# of the Blademarks. A recent convert to the Blood of Vol,
# Shirin has been working with the Order of the Emerald
# Claw and may soon attempt to wrest control of the house
# away from Breven.
#
# The Defenders Guild provides per-
# sonal protection, including skilled body-
# guards and wizards who can place warding
# spells on their charges. The Blademarks
#
# Guild manages mercenary activities
# across Khorvaire. Members of House
# Deneith serve as officers, trainers,
# and strategists, but the rank-and-file
# soldiers of the Blademarks are largely
# hired mercenaries. The hobgoblins of
# Darguun and the elves of Valenar both
# have strong representation in the forces
# of Deneith, but most of the house’s sol-
# diers are human. One noteworthy troop is
# the League of the Bitter Blade. This merce-
# nary band is composed of soldiers who served in
# the Queen's Guard of Cyre and are now left with no war
# to fight and no kingdom to return to.
#
#
#
# shapers; these living weapons become treasured heirlooms
# of the cult, and are passed down from priest to priest.
# Some Khyber cults seek power and may even have a
# vaguely rational plan for acquiring it, but most are driven
# by madness. Regardless of how sane or structured they may
# seem on the surface, the vast majority of cultists are funda-
# mentally unstable. Virtually all cultists have no regard for
# life. Most consider themselves to be the chosen children
# of the Dragon Below, and the lives of the creatures around
# them are no more meaningful than those of insects.
#
# Typical Dragon Below Cultist: Human rogue 2/cleric 2
# (the Dragon Below): CR 4; Medium humanoid; HD 2d6
# plus 2d8; hp 18; Init +6; Spd 30 ft.; AC 16, touch 12, flat-
# footed 14; Base Atk +2; Grp +4; Atk +6 melee (1d6+2/x4,
# masterwork heavy pick) or +4 melee (1d6+2/19-20, short
# sword) or +5 ranged (1d6+2/X3, composite shortbow
# with masterwork arrow); Full Atk +6 melee (1d6+2/x4,
# masterwork heavy pick) or +4 melee (1d6+2/19-20, short
# sword) or +5 ranged (1d6+2/X3, composite shortbow with
# masterwork arrow); SA rebuke undead 2/day (—1, 2d6+1,
# 2nd), sneak attack +1d6; SQ) evasion, trapfinding; AL NE;
# SV Fort +3, Ref +5, Will +4*; Str 14, Dex 15, Con 10, Int
# 12, Wis 14, Cha 8.
#
# Skills and Feats: Balance +4, Bluff +4, Concentration +2,
# Diplomacy +1, Disable Device +6, Escape Artist +7, Gather
# Information +4, Heal +3* Hide +6, Intimidate +1, Jump
# +4, Knowledge (religion) +3, Listen +2* Move Silently
# +7, Search +6, Spellcraft +3, Spot +6*, Survival +3* (when
# following tracks), Tumble +7, Use Rope +4 (involving
# bindings); Augment Summoning”, Improved Initiative,
# Weapon Focus (heavy pick).
#
# *Includes —1 penalty for having the Madness domain.
#
# Languages: Common, Undercommon.
#
# Possessions: Masterwork studded leather, masterwork
# light wooden shield, masterwork heavy pick, short sword.
# composite shortbow (+2 Str bonus) with 15 masterwork
# arrows, holy symbol (the Dragon Below), scroll of doom,
# scroll of magic weapon.
#
# Cleric Spells Prepared (4/4; save DC 12 + spell level):
# 0—detect magic, light, mending, read magic; 1st—cause fear, lesser
# confusion”, obscuring mist, summon monster I.
#
# ” Domain spell. Domains: Dragon Below (Augment
# Summoning as a bonus feat), Madness (once per day, add
# +2 to a single Wisdom-based skill check or Will save before
# the roll is made).
#
# DRAGONMARKED HOUSES
#
# The dragonmarked houses have existed for thousands
# of years. For some reason not completely understood,
# the common races living on the continents of Khorvaire
# and Aerenal developed dragonmarks and the spell-like
# abilities associated with them. Some sages believe that the
# abundance of Eberron dragonshards on these continents
# has something to do with the development of dragonmarks,
# but no one can prove this theory. What is known is that
# humans and elves never manifested dragonmarks while
# living in the Eberron-dragonshard-deficient regions of
# Sarlona and Xen'drik.
#
# Individual dragonmarks appeared within bloodlines,
# and soon family dynasties sprang up to take advantage
# of the dragonmark powers, Each family created an eco-
# nomic empire using the dragonmarks, and the dragon-
# marked houses developed into independent commerce
# states operating across multiple nations. The War of the
# Mark, which ended about fifteen hundred years ago,
# stabilized the houses and ended the threat of aberrant
# and mixed marks that might have destroyed the economy
# of Khorvaire. Today, twelve dragonmarks shared among
# thirteen houses form the basis for economic power across
# the continent.
#
# Agreements reached at the end of the War of the
# Mark formalized tenets and traditions that all the houses
# adhere to. These include rules concerning neutrality (all
# houses make a show of remaining neutral so that they can
# operate in all nations), fair trade and practices, family
# naming conventions, and a ban on marriages between
# houses so that the dragonmarks remain pure.
#
# Family members run each house, with either a matri-
# arch or patriarch serving as the chief executive of both
# family and economic business. House family members
# form an economic aristocracy on par with the royal and
# noble families of the various nations, and family lead-
# ers are literally barons of industry and commerce. Each
# house also employs retainers and hirelings to aid in the
# family business. Those retainers and hirelings who show
# initiative and promise can rise through the ranks to hold
# important positions within the house. The most effective
# and promising of these might be invited into the family
# through marriage to the young scions of the blood, thus
# making sure the bloodline continues.
#
# Even though the house blood flows through the
# veins of every family member, not every one of them has
# a dragonmark; only a small percentage of every genera-
# tion manifests a mark. Among those who do, the least
# mark is the most common to appear, with fewer lesser
# marks, and fewer still greater marks appearing in each
# generation. Those who do develop a dragonmark are
# singled out for great things and have responsibilities
# to the family that scions without marks never have to
# worry about.
#
# HOUSE CANNITH
#
# House Cannith, consisting of humans with the Mark of
# Making, includes alchemists, artificers, and magewrights
# of great skill, as well as the best mundane crafters on the
# continent. House Cannith arose in pre-Galifar Cyre
# almost twenty-five hundred years ago. Originally, the
# Cannith clan consisted of traveling tinkers, repairers,
# and crafters whose burgeoning dragonmarks gave them
# an edge over the competition. As the house developed, it
# turned its attention to supernatural disciplines, study-
# ing alchemy and pioneering the techniques of artificers
# and magewrights. As builders, fixers, and creators, the
# house maintains a lawful outlook. Some of its greatest
# accomplishments include the lightning rail, the war-
# forged, and the high-rising towers of Sharn.
#
# The destruction of Cannith's ancestral estates in Cyre
# and the death of the patriarch have thrown the house into
#
# Q
# =
# ()
# >
# Z
# N
# 5
# Q
# =z
# “
#
#
#
# I
# Zz
# Qo
# =
# N
# Zz
# Le
# ©)
# x
# ©)
#
# 232
#
# chaos. Three leaders have emerged, each intending to
# lead the house into the future. While the situation
# hasn't yet grown as bad as the split in the Mark
# of Shadow family that resulted in the cre-
# ation of a new house, none of the emerging
# Cannith leaders is willing to accept the
# others as the new house patriarch. So far,
# they have reluctantly shared influence
# in the family by concentrating on their
# own regions and not attempting to pull
# the entire family together.
#
# Baron Jorlanna d'Cannith (LN female
# human, wizard 8) operates out of Fairhaven
# and oversees the house's efforts in Aundair,
# Thrane, and the Eldeen Reaches. Baron
# Merrix d'Cannith (LE male human, arti-
# ficer 9/dragonmark heir 3) leads the house's
# activities in Breland, Zilargo, and Darguun from hold-
# ings in Sharn. Baron Zorlan d’Cannith (NE male human,
# artificer 3/sorcerer 4/dragonmark heir 1) controls house
# operations in Karrnath, the Mror Holds, and the Lhazaar
# Principalities from an enclave in Korth.
#
# House Cannith maintains two guilds. The Tinkers
# Guild serves to maintain society by repairing damaged
# structures and vehicles, maintaining infrastructures in
# the major cities, and performing similar crafts. Cannith
# tinkers often travel on circuits between smaller villages,
# using magical and mundane skills to assist communities
# that they pass through. The Fabricators Guild performs
# the greatest works of craft, artifice, and magic. The guild
# is divided into dozens of specialties, including architects,
# elemental binders, alchemists, and armorers. The Fabri-
# cators Guild closely guards the secrets of its creation pat-
# terns. With one of these patterns (each made up of three or
# more sections called schemas), a member of the guild can
# replicate an item faster and with less effort than someone
# working without a pattern.
#
# The services provided by House Cannith are invalu-
# able, and all the nations and dragonmarked houses have
# an interest in maintaining friendly relations with the
# House of Making. House Cannith’s greatest enemy is
# itself. Both Jorlanna and Zorlan seek to gain
# control of the entire house, while Merrix is
# content to rule over the southern interests
# and continue his secret experiments deep
#
# beneath Sharn.
#
# Typical House Cannith Magewright:
# Human magewright 3; CR 2; Medium
# humanoid; HD 3d4+3; hp 10; Init +0;
# Spd 30 ft.; AC 10, touch 10, flat-footed
# 10; Base Atk +1; Grp +0; Atk +0 melee
# (1d3—1, unarmed attack) or +1 ranged
# (1d6 fire, flask of alchemists fire); Full
# Atk +0 melee (1d3—1, unarmed attack) or
# +1 ranged (1d6 fire, flask of alchemists fire);
# SA spells; AL NG: SV Fort +2, Ref +1, Will +5;
# Str 8, Dex 11, Con 12, Int 13, Wis 10, Cha 9.
# Skills and Feats: Concentration +8, Craft (alchemy)
# +5, Craft (blacksmithing) +5, Knowledge (arcana)
#
# +5, Knowledge (architecture and engineering) +5,
# Spellcraft +8; Iron Will, Skill Focus (Concen-
# tration), Skill Focus (Spellcraft).
# Languages: Common, Gnome.
# Magewright Spells Prepared (3/3; save DC
# 11 + spell level): 0—mage hand (3); 1st—mage-
# craft (3).
# Possessions: Artisan’s outfit, artisan's
# tools, flask of alchemist’s fire, 6 tinder-
# twigs, identification papers.
#
# HOUSE DENEITH
#
# The proud humans of House Deneith carry
# the Mark of Sentinel. Born in pre-Galifar
# Karrnath about twenty-six hundred years
# ago, today the house offers the services of
#
# the Defenders Guild and Blademarks Guild,
# one devoted to protection and the other to supply mer-
# cenaries to the highest bidders. From his base of opera-
# tions in Karrlakton, Baron Breven d'Deneith (LN male
# human, aristocrat 3/fighter 3/dragonmark heir 4) con-
# trols the guilds and oversees the activities of the Sentinel
# Marshals who, by ancient decree, provide law and order
# across national boundaries.
#
# Since the rise of Galifar, House Deneith has held to a
# military structure. Heirs of the house are expected to serve
# in the Defenders Guild, the Blademarks, or the Sentinel
# Marshals, and leaders of the house are usually chosen from
# the generals of the Blademarks.
#
# Because of its mercenary forces, Deneith holds the
# most significant military power among the dragonmarked
# houses. In the past, it has strictly abided by its vow of
# neutrality, selling its services to those on both sides of any
# conflict. With the Five Nations weakened by the Last War,
# some within the house feel that it is time for Deneith to
# exercise its power to forge a new kingdom. Chief among
# these activists is Shirin d'Deneith (LE male human,
# rogue 3/fighter 4/dragonmark heir 2), Lord Commander
# of the Blademarks. A recent convert to the Blood of Vol,
# Shirin has been working with the Order of the Emerald
# Claw and may soon attempt to wrest control of the house
# away from Breven.
#
# The Defenders Guild provides per-
# sonal protection, including skilled body-
# guards and wizards who can place warding
# spells on their charges. The Blademarks
#
# Guild manages mercenary activities
# across Khorvaire. Members of House
# Deneith serve as officers, trainers,
# and strategists, but the rank-and-file
# soldiers of the Blademarks are largely
# hired mercenaries. The hobgoblins of
# Darguun and the elves of Valenar both
# have strong representation in the forces
# of Deneith, but most of the house's sol-
# diers are human. One noteworthy troop is
# the League of the Bitter Blade. This merce-
# nary band is composed of soldiers who served in
# the Queen's Guard of Cyre and are now left with no war
# to fight and no kingdom to return to.
#
#
#
# Cannith Catalogue
#
# The following sections describe various useful
# objects that can be usually bought in a Cannith
# enclave, devices which represent recent
# breakthroughs in the dragonmarked House
# applied research.
#
# Aerogel Powder
#
# A smoky powder obtained mixing a noble gas
# with graphene dust, this peculiar substance is
# able to absorb weak magical radiation. Each dose
# can be sprinkled on a single object, obtaining one
# of the following effects:
#
# - the aerogel can automatically suppress
# the dim light radiated by an object
# obtained through the use of the Minor
# Conjuration wizard class feature or by a
# magic item with the Sentinel minor
# property;
#
# - the powder can automatically dispel the
# effects of the use of the Minor Alchemy
# wizard class feature;
#
# - it can suppress the powers of a warlock
# Book of Shadows for 10 minutes.
#
# The price of a dose of Aerogel Powder is 10 gp.
#
# Aluminum Arrows
#
# Made of an extremely light and durable metal,
# these arrows increase the normal and maximum
# range of bows employing them by 10%.
# Moreover, at the end of battle, you can recover 3%
# of your expended Aluminum Arrows by taking a
# minute to search the battlefield.
#
# 20 Aluminum Arrows cost 30 gp.
#
# Carbide Helmet
#
# A tight-fitting black-and-brown helmet, this head
# protection is made of a strong bio-mechanical
# substance. Used by a character with medium or
# heavy armor proficiency, the Carbide Helmet
# increases her Armor Class by 1 (you can benefit
# from only one helmet at a time).
#
# The Carbide Helmet has a price of 30 gp, but itis
# automatically destroyed the first time you are
# subject to a critical hit.
#
# Cannith Catalogue
#
# Ceramic Shard
#
# A Ceramic Shard is a longsword with a blade
# made of magically reinforced and edged white-
# rosy ceramic. Differently from a standard
# longsword, it weights 1 Ib. only and has the
# Finesse property (the property applies also when
# the Shard is used with both hands).
#
# A Ceramic Shard costs 50 gp.
#
# Gravitational Manipulator
#
# You can use the gravitational waves this strange
# belt emits to your advantage during combat.
# When you take the shoving a creature combat
# action, you are considered one size larger than
# your actual size, and you do not suffer
# disadvantage on Strength (Athletics) checks
# when you try the shove aside combat action.
#
# The Gravitational Manipulator can be bought for
# 400 gp.
#
# Longtooth Implant
#
# The Longtooth Implant is an equivocal item
# formed by a couple of metabolic processors
# derived from ancient rakshasa schemas.
#
# A Longtooth shifter can have this Implant
# permanently attached to its fangs for 500 gp. The
# Implant allows the character to inflict an
# additional 1d4 poison damage while using the
# Longtooth Shifting Feature.
#
# Polymer Mirrorshades
#
# Blue reflecting glasses with lenses made of soft,
# synthetic material, the Polymer Mirrorshades are
# infused with abjuration magic and also very
# stylish.
#
# While wearing the Mirrorshades, you can always
# decide to succeed on a saving throw against an
# effect potentially capable of inflicting the blinded
# condition. If you do, the glasses are automatically
# destroyed.
#
# The price of a pair of Polymer Mirrorshades is
# 100 gp.
#
#
#
# Cannith Catalogue 2
#
# The following sections describe various useful
# objects that can be usually bought in a Cannith
# enclave, devices which represent recent
# breakthroughs in the dragonmarked House
# applied research.
#
# Litmus Strips
#
# This carnet contains ten strips of parchment as
# large as a finger, sprinkled with a reduced
# amount of residuum from Siberys dragonshards
# and a powder obtained crushing Khyber’s lichens.
# Their color is normally light yellow, but when
# removed from the carnet and put in contact with
# an object for at least one round, it changes
# according to the object hit points status (the color
# variation requires an additional round). A strip
# turns brilliant orange in color if the object with
# which is in contact lost at least 1 hp but no more
# than half the maximum hit points total, while it
# turns deep red if the object lost more than half its
# hit points. The change in color is irreversible, and
# trying to revert or alter it via magic means
# inevitably causes the strip to be turned into
# ashes.
#
# The price of a carnet of Litmus Strips is 5 gp.
#
# Muck Springers
#
# Made of an extremely robust leather obtained by
# magebred donkeys, these boots include a safety
# mechanism useful while dealing with swamps
# and bogs. When someone wearing a pair of Muck
# Springers sinks in a quicksand pit for at least 3
# feet, the boots’ soles release a couple of large
# springs made of magic energy able to
# automatically eject the subject from the pit,
# having her safely landing in the nearest solid
# space. The mechanism works one time and
# cannot be recharged.
#
# A pair of Muck Springers costs 15 gp.
#
# Metaprocessor
#
# An apparently ordinary item, this box is made of
# light wood and it is not larger than a waterskin.
# When specific substances produced by living
#
# Cannith Catalogue 2
#
# beings are put into the box, the item is capable of
# converting them into useful or otherwise
# interesting objects. The box needs 8 hours to
# process one substance and can convert only one
# material in any given moment:
#
# Input Output
#
# A mass of writhing
# worms (50% of
# probability), a piece of
# soap (49%) or one lb.
# of silver (1%).
#
# A tentacle or
# appendage from a
# creature belonging to
# the Aberration type
#
# A horn or fang froma |1 Ib. of salt.
# creature belonging to
#
# the Beast type
#
# Three scales from any |A minuscule golden
# Dragon nugget worth 1 gp.
#
# One ounce of 1 1b. of copper.
# protoplasmic
#
# substance from the
#
# corpse of a creature
#
# belonging to the Ooze
#
# type
#
# Three leaves or thorns |A hempen rope, 20 ft.
# from any Plant creature | long.
#
# The Metaprocessor has a price of 750 gp.
#
# Everywand
#
# The multipurpose tool coveted by every
# businessman. This device resembles a wand
# made of hard, dark xendrikan wood with four
# different buttons that are set in a row along the
# haft. Pressing one of the wand’s four buttons
# requires an action. A button’s effect lasts until a
# different button is pressed (or the same button is
# pressed again), an action which causes the wand
# to revert to its basic form (which is devoid of any
# power or function).
#
# Pressing button A causes the wand to transform
# into an ink pen equipped with an inexhaustible
# supply of purple ink.

# %%
len(docs_embed), docs_embed.size
# First number is the number of documents, second is I think the number of tokens.
# Out:
# (3, 2304)
